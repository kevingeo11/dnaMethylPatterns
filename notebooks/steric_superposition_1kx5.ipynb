# %%
from pymol import cmd
import Bio.PDB
import pickle

# %%
vdw_radii = {
    "C":1.70,
    "O":1.52,
    "N":1.55,
    "H":1.20,
    "P":1.80,
    "S":1.80
}

sugar_backbone_dna_atoms = [
    "P", "OP1", "OP2", "O5'", "C5'", "C4'", "O4'", "C3'", "O3'", "C2'", "C1'"
    ]

# %%
main_path = '../'
steric_path = main_path + 'superposition/'

pdb_nuclesome = '1KX5'
pdb_dnmt = '3PTA'

# %%
def pickle_dump(data, file):
    with open(file, "wb") as f:
        pickle.dump(data, f, -1)

def remove_water_from_pdb(pdb_file, pdb_name):
    cmd.load(pdb_file, pdb_name)
    cmd.remove('resn hoh')
    cmd.save(pdb_file.replace('.pdb', '_water_rem.pdb'))
    cmd.quit()

def parse_PDB(pdb_file, pdb_id):
    pdb_parser = Bio.PDB.PDBParser(QUIET = True)
    pdb_structure = pdb_parser.get_structure(pdb_id, pdb_file)
                        
    return pdb_structure

def is_steric_clash(atom1,atom2,distance):
    r1 = vdw_radii[atom1]
    r2 = vdw_radii[atom2]
    d_radius = r1+r2
    
    if distance < d_radius:
        return True
    else:
        return False

# %%
def make_superimpose(steric_path, pdb_nuclesome, pdb_dnmt):
    dnmt_file = steric_path + 'pdb_files/' + pdb_dnmt + '.pdb'
    nuc_file = steric_path + 'pdb_files/' + pdb_nuclesome + '.pdb'

    # parse structure
    nucleosome_structure = parse_PDB(nuc_file, 'nuc')
    dnmt_structure = parse_PDB(dnmt_file, 'dnmt')

    model_nuc = nucleosome_structure[0]
    model_dnmt = dnmt_structure[0]

    ################ ATOMS ######################
    len_DNA_part = 12
    
    # DNA strand 1 (B,Y): numbers 1-19
    # DNA strand 2 (C,Z): numbers 20-38
    B_start = 4
    B_end = B_start + len_DNA_part
    C_start = 36 - len_DNA_part
    C_end = 36
    
    #################### DNMT ATOMS ##########################
    # chain A = DNMT1
    # chain B = DNA strand 1
    # chain C = DNA strand 2
    
    dnmt_atoms = []
    range_dnmt1 = range(B_start, B_end)
    range_dnmt2 = range(C_start, C_end)

    #append DNMT DNA atoms to list if in backbone and in middle of DNA (4-15, and 24 to 35)
    nbr_atoms_chain_Y = 0
    for chain in model_dnmt:
        chain_id = chain.id
        #rename for coloring since nucleosome structure has same chain ids
        if chain_id == "A":
            chain.id = "X"
            chain_id = "X"
        if chain_id == "B":
            chain.id = "Y"
            chain_id = "Y"
        if chain_id == "C":
            chain.id = "Z"
            chain_id = "Z"
        for residue in chain:
            res_id = residue.id
            res_info = res_id[0]
            res_pos = res_id[1]
            if res_info == " ":
                #DNA strand 1
                if chain_id == "Y":
                    if res_pos in range_dnmt1:
                        res_name = residue.resname #DA
                        for atom in residue:
                            atom_id = atom.id
                            if atom_id in sugar_backbone_dna_atoms:
                                dnmt_atoms.append(atom)
                                nbr_atoms_chain_Y += 1
                
                #DNA strand 2    
                if chain_id == "Z":
                    if res_pos in range_dnmt2:
                        res_name = residue.resname #DA
                        for atom in residue:
                            atom_id = atom.id
                            if atom_id in sugar_backbone_dna_atoms:
                                dnmt_atoms.append(atom)
    
    # posiition 1 and 136 missing 3 atoms
    dnmt_atoms_pos1 = []
    for a_pos in range(0,len(dnmt_atoms)):
        if a_pos not in [0,1,2]:
            dnmt_atoms_pos1.append(dnmt_atoms[a_pos])
    
    dnmt_atoms_pos136 = []
    for a_pos in range(0,len(dnmt_atoms)):
        if a_pos not in [nbr_atoms_chain_Y,nbr_atoms_chain_Y+1,nbr_atoms_chain_Y+2]:
            dnmt_atoms_pos136.append(dnmt_atoms[a_pos])
    

    '''
    dnmt_atoms [<Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>]
    nucleosome_atoms [<Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>]
    
    dnmt_atoms_pos1 [<Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>]    
    nucleosome_atoms [<Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>]
    '''

    #################### NUCLEOSOME ##########################
    
    I_start = 1
    I_end = I_start+len_DNA_part
    J_start = 148-len_DNA_part
    J_end = 148


    ######## START WHILE LOOP ITERATION DNA NUCLEOSOME ##########
    clash_dict = dict()
    while I_end <= 148:
        print("pos nucleosome", I_start)
        clash_dict[I_start] = dict()
        clash_dict[I_start]["steric_clash_list"] = dict()
        
        ################ NUCLEOSOME ATOMS ######################
        # chain I: DNA strand 1
        # chain J: DNA strand 2
        # chain A: nucleosome complex
        nucleosome_atoms = []
        range_53 = range(I_start,I_end)
        range_35 = range(J_start,J_end)
        
        # do not count them in steric clash, atoms in DNA of nucleosme that are in supoerposition with DNA of DNMT
        range_53_all_superpos = range(I_start-3,I_end+4)
        range_35_all_superpos = range(J_start-4,J_end+3)
        nuc_atoms_all_superpos = set()

        res_nbrs_I_color = []
        res_nbrs_J_color = []
        for chain in model_nuc:
            chain_id = chain.id
    
            pos_res_1based = 1
            for residue in chain:
                if chain_id == "I":
                    if pos_res_1based in range_53:
                        res_id = residue.id
                        res_nbrs_I_color.append(res_id[1])
                        
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                if atom_id in sugar_backbone_dna_atoms:
                                    nucleosome_atoms.append(atom)
                                    
                    if pos_res_1based in range_53_all_superpos:
                        res_id = residue.id
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                #if atom_id in sugar_backbone_dna_atoms:
                                nuc_atoms_all_superpos.add(atom)
                                
                if chain_id == "J":
                    if pos_res_1based in range_35:
                        res_id = residue.id
                        res_nbrs_J_color.append(res_id[1])
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                if atom_id in sugar_backbone_dna_atoms:
                                    nucleosome_atoms.append(atom)
                    
                    if pos_res_1based in range_35_all_superpos:
                        res_id = residue.id
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                nuc_atoms_all_superpos.add(atom)
                pos_res_1based += 1  

        ######### SUPERIMPOSITION ###########
        
        sup = Bio.PDB.Superimposer()
        #if nuc position 1, nuc atoms <Atom P>, <Atom OP1>, <Atom OP2>, are missing -> delete Atom P>, <Atom OP1>, <Atom OP2>, (pos 0-2) from dnmt atoms
        if I_start == 1:
            sup.set_atoms(nucleosome_atoms, dnmt_atoms_pos1)
        elif I_start == 136:
            sup.set_atoms(nucleosome_atoms, dnmt_atoms_pos136)
        else:
            sup.set_atoms(nucleosome_atoms, dnmt_atoms)
        
        sup.apply(model_dnmt.get_atoms())
        
        clash_dict[I_start]["rmsd"] = sup.rms
         
        io = Bio.PDB.PDBIO()
        io.set_structure(dnmt_structure)  # write PDB file
        output_superpos_name = "dnmt_superpos_coords_" + str(I_start)
        dnmt_moved_file = steric_path + "superposition_1KX5/dnmt_coords/" + output_superpos_name + ".pdb"
        io.save(dnmt_moved_file)

        ############ save both structures in one file ############
        if True:
            if I_start != 1: 
                cmd.delete("all")
    
            cmd.load(dnmt_moved_file, output_superpos_name)
            cmd.load(nuc_file, pdb_nuclesome)
            
            cmd.show_as("cartoon")
            cmd.set("cartoon_fancy_helices","1")            
            cmd.color("white","all")
            cmd.color("palecyan","chain I")
            cmd.color("palecyan","chain J")
            
            cmd.color("bluewhite","chain X")
            cmd.color("pink","chain X and resi 755-880")
            cmd.color("lightorange","chain X and resi 972-1100")
            cmd.color("lightblue","chain X and resi 1139-1599")
            cmd.color("firebrick","chain X and resi 647-692")
            cmd.color("slate","chain X and resi 693-754")
            
            cmd.color("white","chain Y")
            cmd.color("white","chain Z")
           
            #color aligned residues nucleosome
            for resi in res_nbrs_I_color:
                if resi < 0:
                    cmd.color("marine","chain I and resi \\"+str(resi))
                else:
                    cmd.color("marine","chain I and resi "+str(resi))
            
            for resi in res_nbrs_J_color:
                if resi < 0:
                    cmd.color("marine","chain J and resi \\"+str(resi))
                else:
                    cmd.color("marine","chain J and resi "+str(resi))
            
           
            methyl_C_pos = res_nbrs_I_color[0]
            if methyl_C_pos < 0:
                cmd.color("cyan","chain I and resi \\"+str(methyl_C_pos))
            else:
                cmd.color("cyan","chain I and resi "+str(methyl_C_pos))   
            
            for resi in range_dnmt1:
                if resi == 4:
                    cmd.color("cyan","chain Y and resi "+str(resi))
                elif resi == 5 or resi == 14 or resi == 15:
                    cmd.color("yellow","chain Y and resi "+str(resi))
                else:
                    cmd.color("orange","chain Y and resi "+str(resi))

            for resi in range_dnmt2:
                if resi == 24 or resi == 25 or resi == 34 or resi == 35:
                    cmd.color("yellow","chain Z and resi "+str(resi))
                else:
                    cmd.color("orange","chain Z and resi "+str(resi))
                 
            cmd.bg_color("black")
            cmd.set('''seq_view''','''1''',quiet=1)
            
            
            cmd.save(steric_path+"superposition_1KX5/superpos_dnmt_nuc_pse/superposition_dnmt_nucleosome_"+str(I_start)+".pse")
            fname = steric_path+"superposition_1KX5/superpos_dnmt_nuc_pse/png/superposition_dnmt_nucleosome_"+str(I_start)+".png"
            cmd.png(fname, width=800, height=700, dpi=300,ray=1,quiet=1)

        ######## get new coordinates #############
        dnmt_moved_structure = parse_PDB(dnmt_moved_file,"dnmt_moved")
        
        
        ########################## CALCULATE STERIC CLASH ###############################
        atom_list_dnmt = Bio.PDB.Selection.unfold_entities(dnmt_moved_structure, 'A') # A for atoms
        atom_list_nuc = Bio.PDB.Selection.unfold_entities(nucleosome_structure, 'A') 
        
        ns = Bio.PDB.NeighborSearch(atom_list_nuc)
        i = 0
        dnmt_atoms_consider_clash = 0
        for atom_dnmt in atom_list_dnmt:
            residue_dnmt = atom_dnmt.get_parent()
            chain_dnmt = residue_dnmt.get_parent()
            if i%1000==0:
                print(str(i)+"/"+str(len(atom_list_dnmt)))
            i += 1
            #chain X: use only protein atoms, not DNA atoms
            if  atom_dnmt.element != "ZN" and atom_dnmt.element != "MN" and atom_dnmt.element != "CL" and chain_dnmt.id == "X":
                dnmt_atoms_consider_clash += 1
                center_coords = atom_dnmt.get_coord()
                neighbors = ns.search(center_coords, 5.0) # 5.0 for distance in angstrom
                
                for neighbor_atom in neighbors:
                    residue_neighbor = neighbor_atom.get_parent()
                    if residue_neighbor.id[0] != "W" and neighbor_atom.element != "ZN" and neighbor_atom.element != "MN" and neighbor_atom.element != "CL" and neighbor_atom not in nuc_atoms_all_superpos:
                        distance = atom_dnmt-neighbor_atom
                        steric_clash = is_steric_clash(atom_dnmt.element,neighbor_atom.element,distance)
                        if steric_clash:
                            chain_neighbor = residue_neighbor.get_parent()
                            dnmt_res_str = chain_dnmt.id+"_"+residue_dnmt.get_resname()+str(residue_dnmt.id[1])
                            dnmt_str = dnmt_res_str+"_"+atom_dnmt.id
                            nuc_str = chain_neighbor.id+"_"+residue_neighbor.get_resname()+str(residue_neighbor.id[1])+"_"+neighbor_atom.id
                            if dnmt_res_str not in clash_dict[I_start]["steric_clash_list"].keys():
                                clash_dict[I_start]["steric_clash_list"][dnmt_res_str] = [[dnmt_str,nuc_str,distance]]
                            else:
                                clash_dict[I_start]["steric_clash_list"][dnmt_res_str].append([dnmt_str,nuc_str,distance])
                
        I_start += 1
        I_end += 1
        J_start -= 1
        J_end -= 1 

    ######## END WHILE LOOP ITERATION DNA NUCLEOSOME ##########
    
    info_nbr_dict = dict()
    info_nbr_dict["model_dnmt_nbr_residues"] = len(list(model_dnmt.get_residues()))
    info_nbr_dict["model_dnmt_nbr_atoms"] = len(list(model_dnmt.get_atoms()))
    info_nbr_dict["dnmt_atoms_consider_clash"] = dnmt_atoms_consider_clash

    if True:
        print('file writing')
        pickle_dump(clash_dict, steric_path + f'clash_{pdb_nuclesome}/' + "clash_dict")
        pickle_dump(info_nbr_dict, steric_path + f'clash_{pdb_nuclesome}/' + "info_nbr_dict")

# %%
make_superimpose(steric_path, pdb_nuclesome, pdb_dnmt)
# Out:
# pos nucleosome 1
#  Ray: render time: 17.86 sec. = 201.6 frames/hour (17.86 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 2
#  Ray: render time: 18.16 sec. = 198.2 frames/hour (36.02 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 3
#  Ray: render time: 17.79 sec. = 202.4 frames/hour (53.81 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 4
#  Ray: render time: 17.10 sec. = 210.6 frames/hour (70.90 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 5
#  Ray: render time: 16.22 sec. = 221.9 frames/hour (87.13 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 6
#  Ray: render time: 16.11 sec. = 223.4 frames/hour (103.24 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 7
#  Ray: render time: 16.08 sec. = 223.9 frames/hour (119.31 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 8
#  Ray: render time: 17.36 sec. = 207.4 frames/hour (136.67 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 9
#  Ray: render time: 17.69 sec. = 203.5 frames/hour (154.36 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 10
#  Ray: render time: 19.28 sec. = 186.7 frames/hour (173.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 11
#  Ray: render time: 19.94 sec. = 180.5 frames/hour (193.59 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 12
#  Ray: render time: 19.37 sec. = 185.8 frames/hour (212.96 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 13
#  Ray: render time: 18.95 sec. = 189.9 frames/hour (231.91 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 14
#  Ray: render time: 18.73 sec. = 192.2 frames/hour (250.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 15
#  Ray: render time: 18.14 sec. = 198.5 frames/hour (268.78 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 16
#  Ray: render time: 17.45 sec. = 206.3 frames/hour (286.23 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 17
#  Ray: render time: 17.20 sec. = 209.3 frames/hour (303.43 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 18
#  Ray: render time: 16.54 sec. = 217.7 frames/hour (319.97 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 19
#  Ray: render time: 17.37 sec. = 207.3 frames/hour (337.33 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 20
#  Ray: render time: 19.06 sec. = 188.8 frames/hour (356.40 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 21
#  Ray: render time: 19.80 sec. = 181.9 frames/hour (376.19 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 22
#  Ray: render time: 19.90 sec. = 180.9 frames/hour (396.10 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 23
#  Ray: render time: 19.85 sec. = 181.4 frames/hour (415.94 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 24
#  Ray: render time: 20.22 sec. = 178.0 frames/hour (436.17 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 25
#  Ray: render time: 18.80 sec. = 191.5 frames/hour (454.97 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 26
#  Ray: render time: 17.28 sec. = 208.3 frames/hour (472.25 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 27
#  Ray: render time: 16.87 sec. = 213.4 frames/hour (489.12 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 28
#  Ray: render time: 16.33 sec. = 220.4 frames/hour (505.45 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 29
#  Ray: render time: 16.62 sec. = 216.5 frames/hour (522.08 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 30
#  Ray: render time: 17.72 sec. = 203.2 frames/hour (539.80 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 31
#  Ray: render time: 18.25 sec. = 197.2 frames/hour (558.05 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 32
#  Ray: render time: 18.87 sec. = 190.7 frames/hour (576.92 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 33
#  Ray: render time: 18.65 sec. = 193.0 frames/hour (595.58 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 34
#  Ray: render time: 17.48 sec. = 205.9 frames/hour (613.06 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 35
#  Ray: render time: 17.29 sec. = 208.2 frames/hour (630.35 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 36
#  Ray: render time: 17.18 sec. = 209.5 frames/hour (647.53 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 37
#  Ray: render time: 16.57 sec. = 217.2 frames/hour (664.10 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 38
#  Ray: render time: 16.39 sec. = 219.6 frames/hour (680.50 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 39
#  Ray: render time: 16.66 sec. = 216.0 frames/hour (697.16 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 40
#  Ray: render time: 17.56 sec. = 205.1 frames/hour (714.72 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 41
#  Ray: render time: 17.96 sec. = 200.5 frames/hour (732.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 42
#  Ray: render time: 18.56 sec. = 193.9 frames/hour (751.24 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 43
#  Ray: render time: 18.51 sec. = 194.5 frames/hour (769.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 44
#  Ray: render time: 18.36 sec. = 196.1 frames/hour (788.11 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 45
#  Ray: render time: 18.43 sec. = 195.3 frames/hour (806.55 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 46
#  Ray: render time: 17.43 sec. = 206.5 frames/hour (823.98 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 47
#  Ray: render time: 16.23 sec. = 221.8 frames/hour (840.21 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 48
#  Ray: render time: 15.81 sec. = 227.7 frames/hour (856.02 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 49
#  Ray: render time: 15.97 sec. = 225.4 frames/hour (872.00 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 50
#  Ray: render time: 16.68 sec. = 215.8 frames/hour (888.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 51
#  Ray: render time: 17.82 sec. = 202.0 frames/hour (906.50 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 52
#  Ray: render time: 18.17 sec. = 198.2 frames/hour (924.67 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 53
#  Ray: render time: 19.29 sec. = 186.6 frames/hour (943.96 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 54
#  Ray: render time: 19.02 sec. = 189.3 frames/hour (962.98 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 55
#  Ray: render time: 18.21 sec. = 197.7 frames/hour (981.19 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 56
#  Ray: render time: 17.58 sec. = 204.8 frames/hour (998.77 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 57
#  Ray: render time: 16.35 sec. = 220.2 frames/hour (1015.12 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 58
#  Ray: render time: 15.31 sec. = 235.1 frames/hour (1030.43 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 59
#  Ray: render time: 15.50 sec. = 232.2 frames/hour (1045.93 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 60
#  Ray: render time: 16.15 sec. = 222.9 frames/hour (1062.08 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 61
#  Ray: render time: 17.38 sec. = 207.2 frames/hour (1079.46 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 62
#  Ray: render time: 17.32 sec. = 207.9 frames/hour (1096.78 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 63
#  Ray: render time: 16.47 sec. = 218.6 frames/hour (1113.24 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 64
#  Ray: render time: 16.02 sec. = 224.7 frames/hour (1129.26 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 65
#  Ray: render time: 15.85 sec. = 227.1 frames/hour (1145.11 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 66
#  Ray: render time: 15.08 sec. = 238.7 frames/hour (1160.20 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 67
#  Ray: render time: 14.44 sec. = 249.2 frames/hour (1174.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 68
#  Ray: render time: 14.68 sec. = 245.2 frames/hour (1189.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 69
#  Ray: render time: 15.12 sec. = 238.1 frames/hour (1204.44 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 70
#  Ray: render time: 15.90 sec. = 226.5 frames/hour (1220.34 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 71
#  Ray: render time: 17.09 sec. = 210.7 frames/hour (1237.43 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 72
#  Ray: render time: 16.94 sec. = 212.5 frames/hour (1254.37 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 73
#  Ray: render time: 16.17 sec. = 222.6 frames/hour (1270.54 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 74
#  Ray: render time: 16.40 sec. = 219.5 frames/hour (1286.94 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 75
#  Ray: render time: 15.91 sec. = 226.3 frames/hour (1302.84 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 76
#  Ray: render time: 15.61 sec. = 230.6 frames/hour (1318.45 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 77
#  Ray: render time: 14.80 sec. = 243.2 frames/hour (1333.25 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 78
#  Ray: render time: 15.29 sec. = 235.5 frames/hour (1348.54 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 79
#  Ray: render time: 15.49 sec. = 232.4 frames/hour (1364.03 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 80
#  Ray: render time: 16.27 sec. = 221.2 frames/hour (1380.30 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 81
#  Ray: render time: 17.34 sec. = 207.7 frames/hour (1397.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 82
#  Ray: render time: 17.20 sec. = 209.3 frames/hour (1414.84 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 83
#  Ray: render time: 17.17 sec. = 209.6 frames/hour (1432.01 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 84
#  Ray: render time: 17.64 sec. = 204.1 frames/hour (1449.65 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 85
#  Ray: render time: 17.58 sec. = 204.8 frames/hour (1467.23 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 86
#  Ray: render time: 17.88 sec. = 201.4 frames/hour (1485.11 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 87
#  Ray: render time: 17.62 sec. = 204.3 frames/hour (1502.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 88
#  Ray: render time: 16.74 sec. = 215.0 frames/hour (1519.47 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 89
#  Ray: render time: 16.45 sec. = 218.8 frames/hour (1535.93 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 90
#  Ray: render time: 15.96 sec. = 225.6 frames/hour (1551.88 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 91
#  Ray: render time: 16.24 sec. = 221.7 frames/hour (1568.12 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 92
#  Ray: render time: 17.09 sec. = 210.6 frames/hour (1585.21 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 93
#  Ray: render time: 19.26 sec. = 186.9 frames/hour (1604.47 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 94
#  Ray: render time: 19.10 sec. = 188.5 frames/hour (1623.57 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 95
#  Ray: render time: 19.26 sec. = 186.9 frames/hour (1642.83 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 96
#  Ray: render time: 19.50 sec. = 184.6 frames/hour (1662.33 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 97
#  Ray: render time: 18.77 sec. = 191.8 frames/hour (1681.09 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 98
#  Ray: render time: 17.66 sec. = 203.9 frames/hour (1698.75 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 99
#  Ray: render time: 16.88 sec. = 213.2 frames/hour (1715.63 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 100
#  Ray: render time: 15.81 sec. = 227.8 frames/hour (1731.44 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 101
#  Ray: render time: 16.30 sec. = 220.8 frames/hour (1747.74 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 102
#  Ray: render time: 16.88 sec. = 213.3 frames/hour (1764.62 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 103
#  Ray: render time: 18.05 sec. = 199.4 frames/hour (1782.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 104
#  Ray: render time: 18.41 sec. = 195.5 frames/hour (1801.09 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 105
#  Ray: render time: 18.83 sec. = 191.2 frames/hour (1819.92 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 106
#  Ray: render time: 18.62 sec. = 193.3 frames/hour (1838.54 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 107
#  Ray: render time: 17.74 sec. = 202.9 frames/hour (1856.28 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 108
#  Ray: render time: 17.02 sec. = 211.5 frames/hour (1873.30 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 109
#  Ray: render time: 16.39 sec. = 219.7 frames/hour (1889.69 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 110
#  Ray: render time: 16.45 sec. = 218.9 frames/hour (1906.13 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 111
#  Ray: render time: 15.88 sec. = 226.6 frames/hour (1922.02 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 112
#  Ray: render time: 16.25 sec. = 221.6 frames/hour (1938.27 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 113
#  Ray: render time: 17.03 sec. = 211.5 frames/hour (1955.29 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 114
#  Ray: render time: 18.11 sec. = 198.7 frames/hour (1973.41 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 115
#  Ray: render time: 17.64 sec. = 204.1 frames/hour (1991.05 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 116
#  Ray: render time: 17.46 sec. = 206.2 frames/hour (2008.51 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 117
#  Ray: render time: 17.69 sec. = 203.5 frames/hour (2026.20 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 118
#  Ray: render time: 17.30 sec. = 208.1 frames/hour (2043.49 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 119
#  Ray: render time: 16.26 sec. = 221.5 frames/hour (2059.75 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 120
#  Ray: render time: 15.69 sec. = 229.4 frames/hour (2075.44 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 121
#  Ray: render time: 15.62 sec. = 230.5 frames/hour (2091.06 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 122
#  Ray: render time: 15.87 sec. = 226.9 frames/hour (2106.92 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 123
#  Ray: render time: 16.69 sec. = 215.7 frames/hour (2123.61 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 124
#  Ray: render time: 16.94 sec. = 212.5 frames/hour (2140.55 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 125
#  Ray: render time: 17.13 sec. = 210.2 frames/hour (2157.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 126
#  Ray: render time: 18.13 sec. = 198.5 frames/hour (2175.81 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 127
#  Ray: render time: 17.46 sec. = 206.1 frames/hour (2193.28 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 128
#  Ray: render time: 17.13 sec. = 210.2 frames/hour (2210.40 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 129
#  Ray: render time: 16.61 sec. = 216.8 frames/hour (2227.01 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 130
#  Ray: render time: 15.56 sec. = 231.4 frames/hour (2242.57 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 131
#  Ray: render time: 15.41 sec. = 233.6 frames/hour (2257.98 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 132
#  Ray: render time: 15.78 sec. = 228.1 frames/hour (2273.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 133
#  Ray: render time: 16.32 sec. = 220.5 frames/hour (2290.08 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 134
#  Ray: render time: 16.45 sec. = 218.9 frames/hour (2306.53 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 135
#  Ray: render time: 17.63 sec. = 204.2 frames/hour (2324.16 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 136
#  Ray: render time: 18.37 sec. = 196.0 frames/hour (2342.53 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# file writing
