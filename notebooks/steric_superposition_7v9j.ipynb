# %%
from pymol import cmd
import Bio.PDB
import pickle

# %%
vdw_radii = {
    "C":1.70,
    "O":1.52,
    "N":1.55,
    "H":1.20,
    "P":1.80,
    "S":1.80
}

sugar_backbone_dna_atoms = [
    "P", "OP1", "OP2", "O5'", "C5'", "C4'", "O4'", "C3'", "O3'", "C2'", "C1'"
    ]

# %%
main_path = '../'
steric_path = main_path + 'superposition/'

pdb_nuclesome = '7V9J'
pdb_dnmt = '3PTA'

# %%
def pickle_dump(data, file):
    with open(file, "wb") as f:
        pickle.dump(data, f, -1)

def remove_water_from_pdb(pdb_file, pdb_name):
    cmd.load(pdb_file, pdb_name)
    cmd.remove('resn hoh')
    cmd.save(pdb_file.replace('.pdb', '_water_rem.pdb'))
    cmd.quit()

def parse_PDB(pdb_file, pdb_id):
    pdb_parser = Bio.PDB.PDBParser(QUIET = True)
    pdb_structure = pdb_parser.get_structure(pdb_id, pdb_file)
                        
    return pdb_structure

def is_steric_clash(atom1,atom2,distance):
    r1 = vdw_radii[atom1]
    r2 = vdw_radii[atom2]
    d_radius = r1+r2
    
    if distance < d_radius:
        return True
    else:
        return False

# %%
def make_superimpose(steric_path, pdb_nuclesome, pdb_dnmt):
    dnmt_file = steric_path + 'pdb_files/' + pdb_dnmt + '.pdb'
    nuc_file = steric_path + 'pdb_files/' + pdb_nuclesome + '.pdb'

    # parse structure
    nucleosome_structure = parse_PDB(nuc_file, 'nuc')
    dnmt_structure = parse_PDB(dnmt_file, 'dnmt')

    model_nuc = nucleosome_structure[0]
    model_dnmt = dnmt_structure[0]

    ################ ATOMS ######################
    len_DNA_part = 12
    
    # DNA strand 1 (B,Y): numbers 1-19
    # DNA strand 2 (C,Z): numbers 20-38
    B_start = 4
    B_end = B_start + len_DNA_part
    C_start = 36 - len_DNA_part  #21 38
    C_end = 36
    
    #################### DNMT ATOMS ##########################
    # chain A = DNMT1
    # chain B = DNA strand 1
    # chain C = DNA strand 2
    
    dnmt_atoms = []
    range_dnmt1 = range(B_start, B_end)
    range_dnmt2 = range(C_start, C_end)

    #append DNMT DNA atoms to list if in backbone and in middle of DNA (4-15, and 24 to 35)
    nbr_atoms_chain_Y = 0
    for chain in model_dnmt:
        chain_id = chain.id
        #rename for coloring since nucleosome structure has same chain ids
        if chain_id == "A":
            chain.id = "X"
            chain_id = "X"
        if chain_id == "B":
            chain.id = "Y"
            chain_id = "Y"
        if chain_id == "C":
            chain.id = "Z"
            chain_id = "Z"
        for residue in chain:
            res_id = residue.id
            res_info = res_id[0]
            res_pos = res_id[1]
            if res_info == " ":
                #DNA strand 1
                if chain_id == "Y":
                    if res_pos in range_dnmt1:
                        res_name = residue.resname #DA
                        for atom in residue:
                            atom_id = atom.id
                            if atom_id in sugar_backbone_dna_atoms:
                                dnmt_atoms.append(atom)
                                nbr_atoms_chain_Y += 1
                
                #DNA strand 2    
                if chain_id == "Z":
                    if res_pos in range_dnmt2:
                        res_name = residue.resname #DA
                        for atom in residue:
                            atom_id = atom.id
                            if atom_id in sugar_backbone_dna_atoms:
                                dnmt_atoms.append(atom)
    
    # posiition 1 and 136 missing 3 atoms
    dnmt_atoms_pos1 = []
    for a_pos in range(0,len(dnmt_atoms)):
        if a_pos not in [0,1,2]:
            dnmt_atoms_pos1.append(dnmt_atoms[a_pos])
    
    dnmt_atoms_pos136 = []
    for a_pos in range(0,len(dnmt_atoms)):
        if a_pos not in [nbr_atoms_chain_Y,nbr_atoms_chain_Y+1,nbr_atoms_chain_Y+2]:
            dnmt_atoms_pos136.append(dnmt_atoms[a_pos])

    dnmt_atoms_ids = [a.id for a in dnmt_atoms]

    '''
    dnmt_atoms [<Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>]
    nucleosome_atoms [<Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>]
    
    dnmt_atoms_pos1 [<Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>]    
    nucleosome_atoms [<Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>, <Atom OP1>, <Atom OP2>, <Atom O5'>, <Atom C5'>, <Atom C4'>, <Atom O4'>, <Atom C3'>, <Atom O3'>, <Atom C2'>, <Atom C1'>, <Atom P>]
    '''

    #################### NUCLEOSOME ##########################
    
    I_start = 127
    I_end = I_start+len_DNA_part
    J_start = 274-len_DNA_part
    J_end = 274

    ######## START WHILE LOOP ITERATION DNA NUCLEOSOME ##########
    clash_dict = dict()
    while I_end <= 274:
        print("pos nucleosome", I_start)
        clash_dict[I_start] = dict()
        clash_dict[I_start]["steric_clash_list"] = dict()
        
        ################ NUCLEOSOME ATOMS ######################
        # chain I: DNA strand 1
        # chain J: DNA strand 2
        # chain A: nucleosome complex
        nucleosome_atoms = []
        range_53 = range(I_start,I_end)
        range_35 = range(J_start,J_end)
        
        # do not count them in steric clash, atoms in DNA of nucleosme that are in supoerposition with DNA of DNMT
        range_53_all_superpos = range(I_start-3,I_end+4)
        range_35_all_superpos = range(J_start-4,J_end+3)
        nuc_atoms_all_superpos = set()

        res_nbrs_I_color = []
        res_nbrs_J_color = []
        for chain in model_nuc:
            chain_id = chain.id
    
            pos_res_1based = 1
            for residue in chain:
                if chain_id == "I":
                    if pos_res_1based in range_53:
                        res_id = residue.id
                        res_nbrs_I_color.append(res_id[1])
                        
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                if atom_id in sugar_backbone_dna_atoms:
                                    nucleosome_atoms.append(atom)
                                    
                    if pos_res_1based in range_53_all_superpos:
                        res_id = residue.id
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                nuc_atoms_all_superpos.add(atom)
                                
                if chain_id == "J":
                    if pos_res_1based in range_35:
                        res_id = residue.id
                        res_nbrs_J_color.append(res_id[1])
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                if atom_id in sugar_backbone_dna_atoms:
                                    nucleosome_atoms.append(atom)
                    
                    if pos_res_1based in range_35_all_superpos:
                        res_id = residue.id
                        res_info = res_id[0]
                        res_pos = res_id[1]
                        if res_info == " ":
                            res_name = residue.resname #DA
                            for atom in residue:
                                atom_id = atom.id
                                nuc_atoms_all_superpos.add(atom)
                pos_res_1based += 1  
    
        nuc_atoms_ids = [a.id for a in nucleosome_atoms]
        assert dnmt_atoms_ids == nuc_atoms_ids

        ######### SUPERIMPOSITION ###########
        
        sup = Bio.PDB.Superimposer()
        sup.set_atoms(nucleosome_atoms, dnmt_atoms)
        
        sup.apply(model_dnmt.get_atoms())
        
        clash_dict[I_start]["rmsd"] = sup.rms
         
        io = Bio.PDB.PDBIO()
        io.set_structure(dnmt_structure) # write PDB file
        output_superpos_name = "dnmt_superpos_coords_" + str(I_start)
        dnmt_moved_file = steric_path + "superposition_7V9J/dnmt_coords/" + output_superpos_name + ".pdb"
        io.save(dnmt_moved_file)

        ############ save both structures in one file ############
        if True:
            if I_start != 1:
                cmd.delete("all")
    
            cmd.load(dnmt_moved_file, output_superpos_name)
            cmd.load(nuc_file, pdb_nuclesome)
            cmd.show_as("cartoon")
            cmd.set("cartoon_fancy_helices","1")
            cmd.color("white","all")
            cmd.color("palecyan","chain I")
            cmd.color("palecyan","chain J")
              
            cmd.color("bluewhite","chain X")
            cmd.color("pink","chain X and resi 755-880")
            cmd.color("lightorange","chain X and resi 972-1100")
            cmd.color("lightblue","chain X and resi 1139-1599")
            cmd.color("firebrick","chain X and resi 647-692")
            cmd.color("slate","chain X and resi 693-754")
            
            cmd.color("white","chain Y")
            cmd.color("white","chain Z")
            
            #color aligned residues nucleosome
            for resi in res_nbrs_I_color:
                if resi < 0:
                    cmd.color("marine","chain I and resi \\"+str(resi))
                else:
                    cmd.color("marine","chain I and resi "+str(resi))
            
            for resi in res_nbrs_J_color:
                if resi < 0:
                    cmd.color("marine","chain J and resi \\"+str(resi))
                else:
                    cmd.color("marine","chain J and resi "+str(resi))
            
           
            methyl_C_pos = res_nbrs_I_color[0]
            if methyl_C_pos < 0:
                cmd.color("cyan","chain I and resi \\"+str(methyl_C_pos))
            else:
                cmd.color("cyan","chain I and resi "+str(methyl_C_pos))   
                        
            for resi in range_dnmt1:
                if resi == 4:
                    cmd.color("cyan","chain Y and resi "+str(resi))
                elif resi == 5 or resi == 14 or resi == 15:
                    cmd.color("yellow","chain Y and resi "+str(resi))
                else:
                    cmd.color("orange","chain Y and resi "+str(resi))

            for resi in range_dnmt2:
                if resi == 24 or resi == 25 or resi == 34 or resi == 35:
                    cmd.color("yellow","chain Z and resi "+str(resi))
                else:
                    cmd.color("orange","chain Z and resi "+str(resi))
                 
            cmd.bg_color("black")
            cmd.set('''seq_view''','''1''',quiet=1)
            
            cmd.save(steric_path+"superposition_7V9J/superpos_dnmt_nuc_pse/superposition_dnmt_nucleosome_"+str(I_start)+".pse")
            fname = steric_path+"superposition_7V9J/superpos_dnmt_nuc_pse/png/superposition_dnmt_nucleosome_"+str(I_start)+".png"
            cmd.png(fname, width=800, height=700, dpi=300,ray=1,quiet=1)

        ######## get new coordinates #############
        dnmt_moved_structure = parse_PDB(dnmt_moved_file, "dnmt_moved")
        
        ########################## CALCULATE STERIC CLASH ###############################
        atom_list_dnmt = Bio.PDB.Selection.unfold_entities(dnmt_moved_structure, 'A') # A for atoms
        atom_list_nuc = Bio.PDB.Selection.unfold_entities(nucleosome_structure, 'A') 
        
        ns = Bio.PDB.NeighborSearch(atom_list_nuc)
        i = 0
        dnmt_atoms_consider_clash = 0
        for atom_dnmt in atom_list_dnmt:
            residue_dnmt = atom_dnmt.get_parent()
            chain_dnmt = residue_dnmt.get_parent()
            if i%1000==0:
                print(str(i)+"/"+str(len(atom_list_dnmt)))
            i += 1
            if  atom_dnmt.element != "ZN" and atom_dnmt.element != "MN" and atom_dnmt.element != "CL" and chain_dnmt.id == "X":
                dnmt_atoms_consider_clash += 1
                center_coords = atom_dnmt.get_coord()
                neighbors = ns.search(center_coords, 5.0) # 5.0 for distance in angstrom
                
                for neighbor_atom in neighbors:
                    residue_neighbor = neighbor_atom.get_parent()
                    if residue_neighbor.id[0] != "W" and neighbor_atom.element != "ZN" and neighbor_atom.element != "MN" and neighbor_atom.element != "CL" and neighbor_atom not in nuc_atoms_all_superpos:
                        distance = atom_dnmt-neighbor_atom
                        steric_clash = is_steric_clash(atom_dnmt.element,neighbor_atom.element,distance)
                        if steric_clash:
                            chain_neighbor = residue_neighbor.get_parent()
                            dnmt_res_str = chain_dnmt.id+"_"+residue_dnmt.get_resname()+str(residue_dnmt.id[1])
                            dnmt_str = dnmt_res_str+"_"+atom_dnmt.id
                            nuc_str = chain_neighbor.id+"_"+residue_neighbor.get_resname()+str(residue_neighbor.id[1])+"_"+neighbor_atom.id
                            if dnmt_res_str not in clash_dict[I_start]["steric_clash_list"].keys():
                                clash_dict[I_start]["steric_clash_list"][dnmt_res_str] = [[dnmt_str,nuc_str,distance]]
                            else:
                                clash_dict[I_start]["steric_clash_list"][dnmt_res_str].append([dnmt_str,nuc_str,distance])
                
        I_start += 1
        I_end += 1
        J_start -= 1
        J_end -= 1 

    ######## END WHILE LOOP ITERATION DNA NUCLEOSOME ##########
    
    #print clash_dict
    info_nbr_dict = dict()
    info_nbr_dict["model_dnmt_nbr_residues"] = len(list(model_dnmt.get_residues()))
    info_nbr_dict["model_dnmt_nbr_atoms"] = len(list(model_dnmt.get_atoms()))
    info_nbr_dict["dnmt_atoms_consider_clash"] = dnmt_atoms_consider_clash

    if True:
        print('file writing')
        pickle_dump(clash_dict, steric_path + f'clash_{pdb_nuclesome}/' + "clash_dict")
        pickle_dump(info_nbr_dict, steric_path + f'clash_{pdb_nuclesome}/' + "info_nbr_dict")

# %%
make_superimpose(steric_path, pdb_nuclesome, pdb_dnmt)
# Out:
# pos nucleosome 127
#  Ray: render time: 52.28 sec. = 68.9 frames/hour (52.28 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 128
#  Ray: render time: 51.81 sec. = 69.5 frames/hour (104.09 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 129
#  Ray: render time: 52.03 sec. = 69.2 frames/hour (156.12 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 130
#  Ray: render time: 51.20 sec. = 70.3 frames/hour (207.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 131
#  Ray: render time: 50.90 sec. = 70.7 frames/hour (258.22 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 132
#  Ray: render time: 50.46 sec. = 71.3 frames/hour (308.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 133
#  Ray: render time: 51.57 sec. = 69.8 frames/hour (360.25 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 134
#  Ray: render time: 51.76 sec. = 69.6 frames/hour (412.01 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 135
#  Ray: render time: 51.25 sec. = 70.2 frames/hour (463.26 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 136
#  Ray: render time: 51.61 sec. = 69.8 frames/hour (514.87 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 137
#  Ray: render time: 51.51 sec. = 69.9 frames/hour (566.38 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 138
#  Ray: render time: 53.85 sec. = 66.8 frames/hour (620.23 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 139
#  Ray: render time: 52.91 sec. = 68.0 frames/hour (673.15 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 140
#  Ray: render time: 49.58 sec. = 72.6 frames/hour (722.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 141
#  Ray: render time: 49.56 sec. = 72.6 frames/hour (772.29 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 142
#  Ray: render time: 49.40 sec. = 72.9 frames/hour (821.69 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 143
#  Ray: render time: 50.71 sec. = 71.0 frames/hour (872.40 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 144
#  Ray: render time: 50.70 sec. = 71.0 frames/hour (923.10 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 145
#  Ray: render time: 50.21 sec. = 71.7 frames/hour (973.30 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 146
#  Ray: render time: 53.95 sec. = 66.7 frames/hour (1027.26 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 147
#  Ray: render time: 54.09 sec. = 66.6 frames/hour (1081.35 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 148
#  Ray: render time: 53.05 sec. = 67.9 frames/hour (1134.40 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 149
#  Ray: render time: 52.74 sec. = 68.3 frames/hour (1187.14 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 150
#  Ray: render time: 52.59 sec. = 68.5 frames/hour (1239.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 151
#  Ray: render time: 51.44 sec. = 70.0 frames/hour (1291.17 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 152
#  Ray: render time: 49.69 sec. = 72.4 frames/hour (1340.86 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 153
#  Ray: render time: 50.50 sec. = 71.3 frames/hour (1391.35 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 154
#  Ray: render time: 51.14 sec. = 70.4 frames/hour (1442.49 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 155
#  Ray: render time: 53.41 sec. = 67.4 frames/hour (1495.90 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 156
#  Ray: render time: 55.72 sec. = 64.6 frames/hour (1551.62 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 157
#  Ray: render time: 55.17 sec. = 65.2 frames/hour (1606.80 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 158
#  Ray: render time: 54.60 sec. = 65.9 frames/hour (1661.40 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 159
#  Ray: render time: 55.11 sec. = 65.3 frames/hour (1716.51 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 160
#  Ray: render time: 52.55 sec. = 68.5 frames/hour (1769.06 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 161
#  Ray: render time: 51.63 sec. = 69.7 frames/hour (1820.70 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 162
#  Ray: render time: 52.37 sec. = 68.7 frames/hour (1873.06 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 163
#  Ray: render time: 52.35 sec. = 68.8 frames/hour (1925.41 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 164
#  Ray: render time: 52.22 sec. = 68.9 frames/hour (1977.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 165
#  Ray: render time: 54.43 sec. = 66.1 frames/hour (2032.07 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 166
#  Ray: render time: 55.03 sec. = 65.4 frames/hour (2087.10 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 167
#  Ray: render time: 56.05 sec. = 64.2 frames/hour (2143.15 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 168
#  Ray: render time: 55.97 sec. = 64.3 frames/hour (2199.11 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 169
#  Ray: render time: 56.31 sec. = 63.9 frames/hour (2255.42 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 170
#  Ray: render time: 55.87 sec. = 64.4 frames/hour (2311.29 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 171
#  Ray: render time: 54.02 sec. = 66.6 frames/hour (2365.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 172
#  Ray: render time: 53.06 sec. = 67.8 frames/hour (2418.38 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 173
#  Ray: render time: 51.62 sec. = 69.7 frames/hour (2470.00 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 174
#  Ray: render time: 50.10 sec. = 71.9 frames/hour (2520.10 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 175
#  Ray: render time: 49.72 sec. = 72.4 frames/hour (2569.82 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 176
#  Ray: render time: 50.46 sec. = 71.4 frames/hour (2620.27 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 177
#  Ray: render time: 50.47 sec. = 71.3 frames/hour (2670.74 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 178
#  Ray: render time: 50.82 sec. = 70.8 frames/hour (2721.56 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 179
#  Ray: render time: 50.93 sec. = 70.7 frames/hour (2772.49 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 180
#  Ray: render time: 49.53 sec. = 72.7 frames/hour (2822.02 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 181
#  Ray: render time: 49.34 sec. = 73.0 frames/hour (2871.36 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 182
#  Ray: render time: 49.03 sec. = 73.4 frames/hour (2920.38 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 183
#  Ray: render time: 49.38 sec. = 72.9 frames/hour (2969.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 184
#  Ray: render time: 49.45 sec. = 72.8 frames/hour (3019.21 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 185
#  Ray: render time: 49.47 sec. = 72.8 frames/hour (3068.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 186
#  Ray: render time: 49.12 sec. = 73.3 frames/hour (3117.80 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 187
#  Ray: render time: 48.93 sec. = 73.6 frames/hour (3166.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 188
#  Ray: render time: 47.97 sec. = 75.1 frames/hour (3214.70 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 189
#  Ray: render time: 46.91 sec. = 76.7 frames/hour (3261.60 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 190
#  Ray: render time: 46.72 sec. = 77.1 frames/hour (3308.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 191
#  Ray: render time: 47.97 sec. = 75.1 frames/hour (3356.28 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 192
#  Ray: render time: 48.77 sec. = 73.8 frames/hour (3405.05 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 193
#  Ray: render time: 48.48 sec. = 74.3 frames/hour (3453.53 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 194
#  Ray: render time: 49.58 sec. = 72.6 frames/hour (3503.11 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 195
#  Ray: render time: 49.36 sec. = 72.9 frames/hour (3552.47 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 196
#  Ray: render time: 49.16 sec. = 73.2 frames/hour (3601.64 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 197
#  Ray: render time: 48.53 sec. = 74.2 frames/hour (3650.17 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 198
#  Ray: render time: 47.52 sec. = 75.8 frames/hour (3697.69 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 199
#  Ray: render time: 46.36 sec. = 77.6 frames/hour (3744.05 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 200
#  Ray: render time: 46.08 sec. = 78.1 frames/hour (3790.13 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 201
#  Ray: render time: 46.95 sec. = 76.7 frames/hour (3837.09 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 202
#  Ray: render time: 49.39 sec. = 72.9 frames/hour (3886.48 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 203
#  Ray: render time: 48.39 sec. = 74.4 frames/hour (3934.87 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 204
#  Ray: render time: 48.78 sec. = 73.8 frames/hour (3983.65 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 205
#  Ray: render time: 49.18 sec. = 73.2 frames/hour (4032.83 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 206
#  Ray: render time: 49.69 sec. = 72.5 frames/hour (4082.52 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 207
#  Ray: render time: 49.07 sec. = 73.4 frames/hour (4131.59 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 208
#  Ray: render time: 49.17 sec. = 73.2 frames/hour (4180.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 209
#  Ray: render time: 48.80 sec. = 73.8 frames/hour (4229.56 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 210
#  Ray: render time: 48.39 sec. = 74.4 frames/hour (4277.96 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 211
#  Ray: render time: 47.30 sec. = 76.1 frames/hour (4325.25 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 212
#  Ray: render time: 46.76 sec. = 77.0 frames/hour (4372.01 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 213
#  Ray: render time: 46.98 sec. = 76.6 frames/hour (4418.99 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 214
#  Ray: render time: 47.56 sec. = 75.7 frames/hour (4466.55 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 215
#  Ray: render time: 48.35 sec. = 74.5 frames/hour (4514.90 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 216
#  Ray: render time: 48.41 sec. = 74.4 frames/hour (4563.31 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 217
#  Ray: render time: 48.35 sec. = 74.5 frames/hour (4611.66 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 218
#  Ray: render time: 48.84 sec. = 73.7 frames/hour (4660.51 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 219
#  Ray: render time: 48.18 sec. = 74.7 frames/hour (4708.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 220
#  Ray: render time: 49.87 sec. = 72.2 frames/hour (4758.55 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 221
#  Ray: render time: 49.28 sec. = 73.0 frames/hour (4807.84 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 222
#  Ray: render time: 46.92 sec. = 76.7 frames/hour (4854.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 223
#  Ray: render time: 48.06 sec. = 74.9 frames/hour (4902.82 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 224
#  Ray: render time: 47.85 sec. = 75.2 frames/hour (4950.66 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 225
#  Ray: render time: 47.54 sec. = 75.7 frames/hour (4998.20 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 226
#  Ray: render time: 48.45 sec. = 74.3 frames/hour (5046.65 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 227
#  Ray: render time: 48.70 sec. = 73.9 frames/hour (5095.35 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 228
#  Ray: render time: 51.22 sec. = 70.3 frames/hour (5146.57 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 229
#  Ray: render time: 52.25 sec. = 68.9 frames/hour (5198.82 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 230
#  Ray: render time: 51.80 sec. = 69.5 frames/hour (5250.62 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 231
#  Ray: render time: 53.69 sec. = 67.1 frames/hour (5304.31 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 232
#  Ray: render time: 52.42 sec. = 68.7 frames/hour (5356.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 233
#  Ray: render time: 49.89 sec. = 72.2 frames/hour (5406.62 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 234
#  Ray: render time: 49.62 sec. = 72.6 frames/hour (5456.24 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 235
#  Ray: render time: 48.83 sec. = 73.7 frames/hour (5505.07 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 236
#  Ray: render time: 48.95 sec. = 73.5 frames/hour (5554.02 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 237
#  Ray: render time: 49.78 sec. = 72.3 frames/hour (5603.80 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 238
#  Ray: render time: 52.15 sec. = 69.0 frames/hour (5655.95 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 239
#  Ray: render time: 52.62 sec. = 68.4 frames/hour (5708.57 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 240
#  Ray: render time: 54.16 sec. = 66.5 frames/hour (5762.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 241
#  Ray: render time: 52.95 sec. = 68.0 frames/hour (5815.68 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 242
#  Ray: render time: 53.52 sec. = 67.3 frames/hour (5869.20 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 243
#  Ray: render time: 53.55 sec. = 67.2 frames/hour (5922.75 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 244
#  Ray: render time: 53.31 sec. = 67.5 frames/hour (5976.06 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 245
#  Ray: render time: 50.66 sec. = 71.1 frames/hour (6026.73 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 246
#  Ray: render time: 50.05 sec. = 71.9 frames/hour (6076.78 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 247
#  Ray: render time: 50.05 sec. = 71.9 frames/hour (6126.83 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 248
#  Ray: render time: 49.94 sec. = 72.1 frames/hour (6176.77 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 249
#  Ray: render time: 51.95 sec. = 69.3 frames/hour (6228.72 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 250
#  Ray: render time: 54.06 sec. = 66.6 frames/hour (6282.77 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 251
#  Ray: render time: 55.41 sec. = 65.0 frames/hour (6338.18 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 252
#  Ray: render time: 54.65 sec. = 65.9 frames/hour (6392.83 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 253
#  Ray: render time: 53.49 sec. = 67.3 frames/hour (6446.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 254
#  Ray: render time: 51.58 sec. = 69.8 frames/hour (6497.90 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 255
#  Ray: render time: 50.86 sec. = 70.8 frames/hour (6548.76 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 256
#  Ray: render time: 50.22 sec. = 71.7 frames/hour (6598.98 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 257
#  Ray: render time: 49.90 sec. = 72.1 frames/hour (6648.87 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 258
#  Ray: render time: 49.67 sec. = 72.5 frames/hour (6698.54 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 259
#  Ray: render time: 49.29 sec. = 73.0 frames/hour (6747.83 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 260
#  Ray: render time: 49.10 sec. = 73.3 frames/hour (6796.93 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 261
#  Ray: render time: 48.39 sec. = 74.4 frames/hour (6845.32 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# pos nucleosome 262
#  Ray: render time: 49.02 sec. = 73.4 frames/hour (6894.34 sec. accum.).
# 0/7989
# 1000/7989
# 2000/7989
# 3000/7989
# 4000/7989
# 5000/7989
# 6000/7989
# 7000/7989
# file writing
